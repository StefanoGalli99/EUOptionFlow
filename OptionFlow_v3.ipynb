# %% [markdown]
# <a href="https://colab.research.google.com/github/StefanoGalli99/EUOptionFlow/blob/main/OptionFlow_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
get_ipython().magic('reset -sf')

# %%
# !pip install requests beautifulsoup4 pandas openpyxl
import os
import pandas as pd
import sqlite3
from pathlib import Path
from urllib.parse import urljoin
import matplotlib.pyplot as plt
import requests # import the requests library
import time
from bs4 import BeautifulSoup  # import BeautifulSoup
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
def download_excel_files():
    # URL del sito web da cui scaricare i file Excel
    base_url = "https://live.euronext.com"
    url = urljoin(base_url, "/en/resources/statistics/nextday-derivatives")

    try:
        # Richiedi all'utente il numero di file da scaricare
        while True:
            num_files = input("Quanti file Excel vuoi scaricare? (Inserisci un numero o 'tutti' per scaricarli tutti): ")
            if num_files.lower() == 'tutti':
                num_files = float('inf')  # Imposta un numero infinito per scaricare tutti i file
                break
            try:
                num_files = int(num_files)
                if num_files <= 0:
                    print("Per favore inserisci un numero positivo.")
                else:
                    break
            except ValueError:
                print("Per favore inserisci un numero valido o 'tutti'.")

        # Effettua una richiesta GET alla pagina web con timeout
        print("\nConnessione al sito web...")
        response = requests.get(url, timeout=30)
        response.raise_for_status()

        # Analizza il contenuto della pagina con BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')
        links = soup.find_all('a')

        # Filtra solo i link Excel
        excel_links = [link for link in links if link.get('href') and link.get('href').endswith('.xlsx')]

        if not excel_links:
            print("Nessun file Excel trovato nella pagina.")
            return

        print(f"\nTrovati {len(excel_links)} file Excel disponibili.")
        if num_files != float('inf'):
            print(f"Verranno scaricati i primi {min(num_files, len(excel_links))} file.")

        # Cartella di destinazione per i file scaricati
        folder_path = "excel_files"
        os.makedirs(folder_path, exist_ok=True)

        files_downloaded = 0
        files_failed = 0

        for i, link in enumerate(excel_links):
            if files_downloaded >= num_files:
                break

            href = link.get('href')
            excel_link = urljoin(base_url, href) if not href.startswith('http') else href
            file_name = os.path.basename(href)
            file_path = os.path.join(folder_path, file_name)

            # Controllo se il file esiste già
            if os.path.exists(file_path):
                print(f"\nIl file '{file_name}' esiste già. Salto il download.")
                continue

            try:
                time.sleep(1)
                print(f"\nDownloading {file_name} ({files_downloaded + 1}/{min(num_files, len(excel_links))})...")
                excel_file = requests.get(excel_link, timeout=30)
                excel_file.raise_for_status()

                # Verifica che il contenuto sia un file Excel
                content_type = excel_file.headers.get('content-type', '')
                if 'application/vnd.openxmlformats-officedocument.spreadsheetml' not in content_type:
                    print(f"Attenzione: Il file {file_name} potrebbe non essere un file Excel valido.")

                with open(file_path, "wb") as f:
                    f.write(excel_file.content)

                files_downloaded += 1
                print(f"File '{file_name}' scaricato con successo.")

            except requests.RequestException as e:
                files_failed += 1
                print(f"Errore nel download del file {file_name}: {e}")

        # Report finale
        print("\nRiepilogo download:")
        print(f"File scaricati con successo: {files_downloaded}")
        print(f"File non scaricati a causa di errori: {files_failed}")
        print(f"I file sono stati salvati in: {os.path.abspath(folder_path)}")

    except requests.RequestException as e:
        print(f"Errore nell'accesso alla pagina web: {e}")
    except Exception as e:
        print(f"Errore imprevisto: {e}")

if __name__ == "__main__":
    download_excel_files()
# Out:
# Quanti file Excel vuoi scaricare? (Inserisci un numero o 'tutti' per scaricarli tutti): 5
#
# Connessione al sito web...
#
# Trovati 5538 file Excel disponibili.
# Verranno scaricati i primi 5 file.
#
# Downloading Derivatives%2020241024.xlsx (1/5)...
# File 'Derivatives%2020241024.xlsx' scaricato con successo.
#
# Il file 'Derivatives%2020241024.xlsx' esiste già. Salto il download.
#
# Downloading Derivatives%2020241023.xlsx (2/5)...
# File 'Derivatives%2020241023.xlsx' scaricato con successo.
#
# Il file 'Derivatives%2020241023.xlsx' esiste già. Salto il download.
#
# Downloading Derivatives%2020241022.xlsx (3/5)...
# File 'Derivatives%2020241022.xlsx' scaricato con successo.
#
# Il file 'Derivatives%2020241022.xlsx' esiste già. Salto il download.
#
# Downloading Derivatives%2020241021.xlsx (4/5)...
# File 'Derivatives%2020241021.xlsx' scaricato con successo.
#
# Il file 'Derivatives%2020241021.xlsx' esiste già. Salto il download.
#
# Downloading Derivatives%2020241018.xlsx (5/5)...
# File 'Derivatives%2020241018.xlsx' scaricato con successo.
#
# Riepilogo download:
# File scaricati con successo: 5
# File non scaricati a causa di errori: 0
# I file sono stati salvati in: /content/excel_files

# %%
# Inizializzazione delle variabili
conn = None

# %%
# Creazione del database e tabella
conn = sqlite3.connect('financial_data.db')
cursor = conn.cursor()
cursor.execute("CREATE TABLE IF NOT EXISTS companies (id INTEGER PRIMARY KEY, name TEXT UNIQUE)")

# Set per tenere traccia delle aziende e della blacklist
processed_companies = set()
blacklist = set()

# Percorso della cartella
folder_path = 'excel_files'
# Elenco dei file Excel nella cartella
excel_files = [f for f in os.listdir(folder_path) if f.endswith('.xlsx')]
print(f"Trovati {len(excel_files)} file Excel nella cartella '{folder_path}'.")

# Limita a 2 file per test
for file_name in excel_files[:2]:
    print(f"Processing file: {file_name}")  # Messaggio di debug
    file_path = os.path.join(folder_path, file_name)

    # Leggi il terzo foglio del file Excel
    df = pd.read_excel(file_path, sheet_name=2, header=None, skiprows=4)  # Salta le prime 4 righe

    for row_idx, row in df.iterrows():
        potential_name = row[5]  # La sesta colonna è in posizione 5

        # Controlla se il nome è NaN
        if pd.isna(potential_name):
            print("IL NOME DI QUESTA RIGA è NULLO")
            continue  # Se il nome è NaN, passa alla prossima iterazione

        base_name = potential_name.split('-')[0].strip()  # Estrarre la parte prima del trattino

        # Controlla se il derivato è un future, una dividend option o una european option
        if "future" in potential_name.lower() or "dividend" in potential_name.lower() or "european" in potential_name.lower():
            continue  # Salta se contiene "future", "dividend" o "european"

        # Controlla se il nome è già stato processato o è nella blacklist
        if base_name in processed_companies or base_name in blacklist:
            continue

        # Richiede input per confermare il nome
        response = input(
            f"File: '{file_name}', Riga: {row_idx + 5}, Nome azienda (completo): '{potential_name}': "
            "Questa cella contiene il nome di un'azienda? (s/no): "
        ).strip().lower()

        if response == 's':
            # Aggiungi solo la parte prima del trattino
            cursor.execute("INSERT OR IGNORE INTO companies (name) VALUES (?)", (base_name,))
            processed_companies.add(base_name)
            print(f"Azienda aggiunta: {base_name}")  # Messaggio di conferma
        else:
            # Aggiungi alla blacklist se non è valido
            blacklist.add(base_name)
            print(f"Azienda aggiunta alla blacklist: {potential_name}")

# Salva le modifiche e chiudi la connessione
conn.commit()
conn.close()
print("Tabella delle aziende popolata con successo.")
# Out:
# Trovati 5 file Excel nella cartella 'excel_files'.
# Processing file: Derivatives%2020241022.xlsx
# File: 'Derivatives%2020241022.xlsx', Riga: 25, Nome azienda (completo): 'AEX Daily Option - 22nd': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: AEX Daily Option
# File: 'Derivatives%2020241022.xlsx', Riga: 235, Nome azienda (completo): 'AEX Index - Mini Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: AEX Index
# File: 'Derivatives%2020241022.xlsx', Riga: 427, Nome azienda (completo): 'AEX Index Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: AEX Index Option
# File: 'Derivatives%2020241022.xlsx', Riga: 957, Nome azienda (completo): 'AEX Weekly - 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: AEX Weekly
# File: 'Derivatives%2020241022.xlsx', Riga: 1281, Nome azienda (completo): 'PSI20 Index Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: PSI20 Index Option
# File: 'Derivatives%2020241022.xlsx', Riga: 2889, Nome azienda (completo): 'Distribuidora Internacional de Alimentacion SA - S': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Distribuidora Internacional de Alimentacion SA
# File: 'Derivatives%2020241022.xlsx', Riga: 5516, Nome azienda (completo): 'ABN AMRO Bank - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: ABN AMRO Bank
# File: 'Derivatives%2020241022.xlsx', Riga: 5936, Nome azienda (completo): 'AEGON': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: AEGON
# File: 'Derivatives%2020241022.xlsx', Riga: 6216, Nome azienda (completo): 'AEGON Weekly Option - Week 1': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: AEGON Weekly Option
# File: 'Derivatives%2020241022.xlsx', Riga: 6328, Nome azienda (completo): 'AKZO NOBEL': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: AKZO NOBEL
# File: 'Derivatives%2020241022.xlsx', Riga: 6610, Nome azienda (completo): 'AMG N.V.': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: AMG N.V.
# File: 'Derivatives%2020241022.xlsx', Riga: 7040, Nome azienda (completo): 'ASM INTERNATIONAL N.V.': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: ASM INTERNATIONAL N.V.
# File: 'Derivatives%2020241022.xlsx', Riga: 7398, Nome azienda (completo): 'ASM International N.V. - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: ASM International N.V.
# File: 'Derivatives%2020241022.xlsx', Riga: 7510, Nome azienda (completo): 'ASML Holding NV': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: ASML Holding NV
# File: 'Derivatives%2020241022.xlsx', Riga: 8534, Nome azienda (completo): 'ASR Nederland - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: ASR Nederland
# File: 'Derivatives%2020241022.xlsx', Riga: 8724, Nome azienda (completo): 'Aalberts': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Aalberts
# File: 'Derivatives%2020241022.xlsx', Riga: 8954, Nome azienda (completo): 'Adidas - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Adidas
# File: 'Derivatives%2020241022.xlsx', Riga: 9416, Nome azienda (completo): 'Adyen (10) - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Adyen (10)
# File: 'Derivatives%2020241022.xlsx', Riga: 10068, Nome azienda (completo): 'Ahold Delhaize, Koninklijke': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Ahold Delhaize, Koninklijke
# File: 'Derivatives%2020241022.xlsx', Riga: 10442, Nome azienda (completo): 'Aib Group - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Aib Group
# File: 'Derivatives%2020241022.xlsx', Riga: 10528, Nome azienda (completo): 'Air France-KLM': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Air France
# File: 'Derivatives%2020241022.xlsx', Riga: 10900, Nome azienda (completo): 'Akzo Nobel NV - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Akzo Nobel NV
# File: 'Derivatives%2020241022.xlsx', Riga: 10992, Nome azienda (completo): 'Alfen - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Alfen
# File: 'Derivatives%2020241022.xlsx', Riga: 11390, Nome azienda (completo): 'Allfunds Group PLC - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Allfunds Group PLC
# File: 'Derivatives%2020241022.xlsx', Riga: 11474, Nome azienda (completo): 'Allianz - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Allianz
# File: 'Derivatives%2020241022.xlsx', Riga: 11822, Nome azienda (completo): 'Aperam Stnd Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Aperam Stnd Option
# File: 'Derivatives%2020241022.xlsx', Riga: 12032, Nome azienda (completo): 'Arcadis N.V': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Arcadis N.V
# File: 'Derivatives%2020241022.xlsx', Riga: 12238, Nome azienda (completo): 'Arcelor Mittal': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Arcelor Mittal
# File: 'Derivatives%2020241022.xlsx', Riga: 12798, Nome azienda (completo): 'ArcelorMittal Weekly Option - 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: ArcelorMittal Weekly Option
# File: 'Derivatives%2020241022.xlsx', Riga: 12924, Nome azienda (completo): 'BASF - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: BASF
# File: 'Derivatives%2020241022.xlsx', Riga: 13336, Nome azienda (completo): 'BE Semiconductor Industries NV - Stnd Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: BE Semiconductor Industries NV
# File: 'Derivatives%2020241022.xlsx', Riga: 13866, Nome azienda (completo): 'BMW - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: BMW
# File: 'Derivatives%2020241022.xlsx', Riga: 14346, Nome azienda (completo): 'Bank of Ireland - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Bank of Ireland
# File: 'Derivatives%2020241022.xlsx', Riga: 14436, Nome azienda (completo): 'Basic-Fit - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Basic
# File: 'Derivatives%2020241022.xlsx', Riga: 14636, Nome azienda (completo): 'Bayer - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Bayer
# File: 'Derivatives%2020241022.xlsx', Riga: 15208, Nome azienda (completo): 'Beiersdorf - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Beiersdorf
# File: 'Derivatives%2020241022.xlsx', Riga: 15456, Nome azienda (completo): 'Brenntag - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Brenntag
# File: 'Derivatives%2020241022.xlsx', Riga: 15708, Nome azienda (completo): 'Brunel International NV Stnd Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Brunel International NV Stnd Option
# File: 'Derivatives%2020241022.xlsx', Riga: 15860, Nome azienda (completo): 'CTP NV - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: CTP NV
# File: 'Derivatives%2020241022.xlsx', Riga: 15946, Nome azienda (completo): 'Coca-Cola Europacific Partners - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Coca
# File: 'Derivatives%2020241022.xlsx', Riga: 16024, Nome azienda (completo): 'Commerzbank - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Commerzbank
# File: 'Derivatives%2020241022.xlsx', Riga: 16276, Nome azienda (completo): 'Continental - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Continental
# File: 'Derivatives%2020241022.xlsx', Riga: 16608, Nome azienda (completo): 'Corbion NV': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Corbion NV
# File: 'Derivatives%2020241022.xlsx', Riga: 16876, Nome azienda (completo): 'DSM-Firmenich': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: DSM
# File: 'Derivatives%2020241022.xlsx', Riga: 17292, Nome azienda (completo): 'Daimler Truck Holding - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Daimler Truck Holding
# File: 'Derivatives%2020241022.xlsx', Riga: 17586, Nome azienda (completo): 'Deutsche Bank - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Deutsche Bank
# File: 'Derivatives%2020241022.xlsx', Riga: 17988, Nome azienda (completo): 'Deutsche Boerse - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Deutsche Boerse
# File: 'Derivatives%2020241022.xlsx', Riga: 18228, Nome azienda (completo): 'Deutsche Lufthansa - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Deutsche Lufthansa
# File: 'Derivatives%2020241022.xlsx', Riga: 18622, Nome azienda (completo): 'Deutsche Post - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Deutsche Post
# File: 'Derivatives%2020241022.xlsx', Riga: 18976, Nome azienda (completo): 'Deutsche Telekom - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Deutsche Telekom
# File: 'Derivatives%2020241022.xlsx', Riga: 19412, Nome azienda (completo): 'E.ON - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: E.ON
# File: 'Derivatives%2020241022.xlsx', Riga: 19738, Nome azienda (completo): 'EUE Stock Option (Underlying: iShares Core EURO STOXX 50 UCI': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: EUE Stock Option (Underlying: iShares Core EURO STOXX 50 UCI
# File: 'Derivatives%2020241022.xlsx', Riga: 19920, Nome azienda (completo): 'Ebusco Holding N.V. - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Ebusco Holding N.V.
# File: 'Derivatives%2020241022.xlsx', Riga: 20044, Nome azienda (completo): 'Eurocommercial Properties - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Eurocommercial Properties
# File: 'Derivatives%2020241022.xlsx', Riga: 20194, Nome azienda (completo): 'Euronext - Stnd Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Euronext
# File: 'Derivatives%2020241022.xlsx', Riga: 20344, Nome azienda (completo): 'Exor NV - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Exor NV
# File: 'Derivatives%2020241022.xlsx', Riga: 20514, Nome azienda (completo): 'FUGRO': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: FUGRO
# File: 'Derivatives%2020241022.xlsx', Riga: 20758, Nome azienda (completo): 'Ferrovial - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Ferrovial
# File: 'Derivatives%2020241022.xlsx', Riga: 20898, Nome azienda (completo): 'Flow Traders - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Flow Traders
# File: 'Derivatives%2020241022.xlsx', Riga: 21118, Nome azienda (completo): 'Fresenius - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Fresenius
# File: 'Derivatives%2020241022.xlsx', Riga: 21528, Nome azienda (completo): 'Glanbia - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Glanbia
# File: 'Derivatives%2020241022.xlsx', Riga: 21618, Nome azienda (completo): 'HEINEKEN': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: HEINEKEN
# File: 'Derivatives%2020241022.xlsx', Riga: 21882, Nome azienda (completo): 'Hannover Rueck - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Hannover Rueck
# File: 'Derivatives%2020241022.xlsx', Riga: 22132, Nome azienda (completo): 'Heidelberger Materials - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Heidelberger Materials
# File: 'Derivatives%2020241022.xlsx', Riga: 22382, Nome azienda (completo): 'Heijmans NV Koninklijke - STND OPT': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Heijmans NV Koninklijke
# File: 'Derivatives%2020241022.xlsx', Riga: 22576, Nome azienda (completo): 'Heineken NV - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Heineken NV
# File: 'Derivatives%2020241022.xlsx', Riga: 22664, Nome azienda (completo): 'Henkel - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Henkel
# File: 'Derivatives%2020241022.xlsx', Riga: 22890, Nome azienda (completo): 'Henkel pref. - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Henkel pref.
# File: 'Derivatives%2020241022.xlsx', Riga: 23134, Nome azienda (completo): 'IMCD - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: IMCD
# File: 'Derivatives%2020241022.xlsx', Riga: 23354, Nome azienda (completo): 'ING Groep': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: ING Groep
# File: 'Derivatives%2020241022.xlsx', Riga: 23872, Nome azienda (completo): 'ING Groep Weekly Option - 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: ING Groep Weekly Option
# File: 'Derivatives%2020241022.xlsx', Riga: 23986, Nome azienda (completo): 'Infineon Technologies - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Infineon Technologies
# File: 'Derivatives%2020241022.xlsx', Riga: 24412, Nome azienda (completo): 'Inpost S.A. - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Inpost S.A.
# File: 'Derivatives%2020241022.xlsx', Riga: 24574, Nome azienda (completo): 'JDE Peet's - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: JDE Peet's
# File: 'Derivatives%2020241022.xlsx', Riga: 24782, Nome azienda (completo): 'Just Eat Takeaway.com - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Just Eat Takeaway.com
# File: 'Derivatives%2020241022.xlsx', Riga: 25210, Nome azienda (completo): 'K+S AG - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: K+S AG
# File: 'Derivatives%2020241022.xlsx', Riga: 25648, Nome azienda (completo): 'KONINKLIJKE KPN NV': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: KONINKLIJKE KPN NV
# File: 'Derivatives%2020241022.xlsx', Riga: 25892, Nome azienda (completo): 'KONINKLIJKE VOPAK NV': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: KONINKLIJKE VOPAK NV
# File: 'Derivatives%2020241022.xlsx', Riga: 26068, Nome azienda (completo): 'Kerry Group - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Kerry Group
# File: 'Derivatives%2020241022.xlsx', Riga: 26148, Nome azienda (completo): 'Kingspan Group - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Kingspan Group
# File: 'Derivatives%2020241022.xlsx', Riga: 26230, Nome azienda (completo): 'Klepierre SA': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Klepierre SA
# File: 'Derivatives%2020241022.xlsx', Riga: 26420, Nome azienda (completo): 'Koninklijke BAM Groep N.V': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Koninklijke BAM Groep N.V
# File: 'Derivatives%2020241022.xlsx', Riga: 26690, Nome azienda (completo): 'MTU Aero Engines - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: MTU Aero Engines
# File: 'Derivatives%2020241022.xlsx', Riga: 26962, Nome azienda (completo): 'Mercedes-Benz - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Mercedes
# File: 'Derivatives%2020241022.xlsx', Riga: 27364, Nome azienda (completo): 'Merck - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Merck
# File: 'Derivatives%2020241022.xlsx', Riga: 27642, Nome azienda (completo): 'Munich Re - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Munich Re
# File: 'Derivatives%2020241022.xlsx', Riga: 28074, Nome azienda (completo): 'NN Group NV - Stnd Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: NN Group NV
# File: 'Derivatives%2020241022.xlsx', Riga: 28348, Nome azienda (completo): 'OCI NV STND OPT': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: OCI NV STND OPT
# File: 'Derivatives%2020241022.xlsx', Riga: 28652, Nome azienda (completo): 'Pharming Group  - Stnd Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Pharming Group
# File: 'Derivatives%2020241022.xlsx', Riga: 28752, Nome azienda (completo): 'Philips NV Koninklijke': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Philips NV Koninklijke
# File: 'Derivatives%2020241022.xlsx', Riga: 29514, Nome azienda (completo): 'Porsche Automobil Holding pref. - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Porsche Automobil Holding pref.
# File: 'Derivatives%2020241022.xlsx', Riga: 29732, Nome azienda (completo): 'Porsche pref. - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Porsche pref.
# File: 'Derivatives%2020241022.xlsx', Riga: 29972, Nome azienda (completo): 'PostNL N.V Stnd Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: PostNL N.V Stnd Option
# File: 'Derivatives%2020241022.xlsx', Riga: 30156, Nome azienda (completo): 'PostNL N.V. - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: PostNL N.V.
# File: 'Derivatives%2020241022.xlsx', Riga: 30240, Nome azienda (completo): 'ProSieben Sat 1 Media AG - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: ProSieben Sat 1 Media AG
# File: 'Derivatives%2020241022.xlsx', Riga: 30670, Nome azienda (completo): 'Prosus - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Prosus
# File: 'Derivatives%2020241022.xlsx', Riga: 31224, Nome azienda (completo): 'Qiagen - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Qiagen
# File: 'Derivatives%2020241022.xlsx', Riga: 31466, Nome azienda (completo): 'RANDSTAD NV': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: RANDSTAD NV
# File: 'Derivatives%2020241022.xlsx', Riga: 31758, Nome azienda (completo): 'RELX (EUR) - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: RELX (EUR)
# File: 'Derivatives%2020241022.xlsx', Riga: 32062, Nome azienda (completo): 'RWE AG - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: RWE AG
# File: 'Derivatives%2020241022.xlsx', Riga: 32402, Nome azienda (completo): 'Rheinmetall - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Rheinmetall
# File: 'Derivatives%2020241022.xlsx', Riga: 32666, Nome azienda (completo): 'Ryanair - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Ryanair
# File: 'Derivatives%2020241022.xlsx', Riga: 32750, Nome azienda (completo): 'SAP - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: SAP
# File: 'Derivatives%2020241022.xlsx', Riga: 33226, Nome azienda (completo): 'SBM Offshore NV': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: SBM Offshore NV
# File: 'Derivatives%2020241022.xlsx', Riga: 33536, Nome azienda (completo): 'Sartorius pref. - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Sartorius pref.
# File: 'Derivatives%2020241022.xlsx', Riga: 33862, Nome azienda (completo): 'Shell': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Shell
# File: 'Derivatives%2020241022.xlsx', Riga: 34400, Nome azienda (completo): 'Shell Weekly Option - 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Shell Weekly Option
# File: 'Derivatives%2020241022.xlsx', Riga: 34496, Nome azienda (completo): 'Siemens AG  - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Siemens AG
# File: 'Derivatives%2020241022.xlsx', Riga: 34890, Nome azienda (completo): 'Siemens Energy AG  - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Siemens Energy AG
# File: 'Derivatives%2020241022.xlsx', Riga: 35654, Nome azienda (completo): 'Siemens Healthineers - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Siemens Healthineers
# File: 'Derivatives%2020241022.xlsx', Riga: 35908, Nome azienda (completo): 'Sif Holding - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Sif Holding
# File: 'Derivatives%2020241022.xlsx', Riga: 36004, Nome azienda (completo): 'Signify - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Signify
# File: 'Derivatives%2020241022.xlsx', Riga: 36226, Nome azienda (completo): 'Sligro Food Group NV - Stnd Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Sligro Food Group NV
# File: 'Derivatives%2020241022.xlsx', Riga: 36356, Nome azienda (completo): 'Symrise - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Symrise
# File: 'Derivatives%2020241022.xlsx', Riga: 36614, Nome azienda (completo): 'TKH Group NV Stnd Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: TKH Group NV Stnd Option
# File: 'Derivatives%2020241022.xlsx', Riga: 36820, Nome azienda (completo): 'Tom Tom Individual Equity Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Tom Tom Individual Equity Option
# File: 'Derivatives%2020241022.xlsx', Riga: 37046, Nome azienda (completo): 'UNILEVER PLC': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: UNILEVER PLC
# File: 'Derivatives%2020241022.xlsx', Riga: 37578, Nome azienda (completo): 'Unibail-Rodamco-Westfield - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Unibail
# File: 'Derivatives%2020241022.xlsx', Riga: 38014, Nome azienda (completo): 'Unilever PLC - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Unilever PLC
# File: 'Derivatives%2020241022.xlsx', Riga: 38118, Nome azienda (completo): 'Universal Music Group - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Universal Music Group
# File: 'Derivatives%2020241022.xlsx', Riga: 38328, Nome azienda (completo): 'Volkswagen pref - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Volkswagen pref
# File: 'Derivatives%2020241022.xlsx', Riga: 38748, Nome azienda (completo): 'Vonovia - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Vonovia
# File: 'Derivatives%2020241022.xlsx', Riga: 39008, Nome azienda (completo): 'WERELDHAVE N.V.': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: WERELDHAVE N.V.
# File: 'Derivatives%2020241022.xlsx', Riga: 39158, Nome azienda (completo): 'WOLTERS-KLUWER': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: WOLTERS
# File: 'Derivatives%2020241022.xlsx', Riga: 39364, Nome azienda (completo): 'Zalando - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Zalando
# File: 'Derivatives%2020241022.xlsx', Riga: 39616, Nome azienda (completo): 'ageas NV/SA': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: ageas NV/SA
# File: 'Derivatives%2020241022.xlsx', Riga: 39834, Nome azienda (completo): 'BEL 20 INDEX OPTION': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: BEL 20 INDEX OPTION
# File: 'Derivatives%2020241022.xlsx', Riga: 40302, Nome azienda (completo): 'AGFA GEVAERT': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: AGFA GEVAERT
# File: 'Derivatives%2020241022.xlsx', Riga: 40450, Nome azienda (completo): 'Ackermans & van Haaren NV - Std Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Ackermans & van Haaren NV
# File: 'Derivatives%2020241022.xlsx', Riga: 40560, Nome azienda (completo): 'Aedifica - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Aedifica
# File: 'Derivatives%2020241022.xlsx', Riga: 40644, Nome azienda (completo): 'Anheuser-Busch InBev': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Anheuser
# File: 'Derivatives%2020241022.xlsx', Riga: 40964, Nome azienda (completo): 'Argenx - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Argenx
# File: 'Derivatives%2020241022.xlsx', Riga: 41216, Nome azienda (completo): 'Azelis Group NV - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Azelis Group NV
# File: 'Derivatives%2020241022.xlsx', Riga: 41308, Nome azienda (completo): 'Barco NV': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Barco NV
# File: 'Derivatives%2020241022.xlsx', Riga: 41486, Nome azienda (completo): 'Bekaert NV Stnd Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Bekaert NV Stnd Option
# File: 'Derivatives%2020241022.xlsx', Riga: 41672, Nome azienda (completo): 'Cofinimmo - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Cofinimmo
# File: 'Derivatives%2020241022.xlsx', Riga: 41760, Nome azienda (completo): 'Colruyt N.V.': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Colruyt N.V.
# File: 'Derivatives%2020241022.xlsx', Riga: 41960, Nome azienda (completo): 'D'Ieteren Group- Spotlight Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: D'Ieteren Group
# File: 'Derivatives%2020241022.xlsx', Riga: 42054, Nome azienda (completo): 'Elia Group - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Elia Group
# File: 'Derivatives%2020241022.xlsx', Riga: 42156, Nome azienda (completo): 'Fagron STND OPT': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Fagron STND OPT
# File: 'Derivatives%2020241022.xlsx', Riga: 42290, Nome azienda (completo): 'GBL': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: GBL
# File: 'Derivatives%2020241022.xlsx', Riga: 42440, Nome azienda (completo): 'Galapagos - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Galapagos
# File: 'Derivatives%2020241022.xlsx', Riga: 42582, Nome azienda (completo): 'Galapagos NV Stnd Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Galapagos NV Stnd Option
# File: 'Derivatives%2020241022.xlsx', Riga: 42852, Nome azienda (completo): 'IBA - Spotlight Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: IBA
# File: 'Derivatives%2020241022.xlsx', Riga: 42954, Nome azienda (completo): 'KBC Groep - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: KBC Groep
# File: 'Derivatives%2020241022.xlsx', Riga: 43060, Nome azienda (completo): 'KBC Groep NV': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: KBC Groep NV
# File: 'Derivatives%2020241022.xlsx', Riga: 43236, Nome azienda (completo): 'Melexis - Stnd Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Melexis
# File: 'Derivatives%2020241022.xlsx', Riga: 43402, Nome azienda (completo): 'Ontex - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Ontex
# File: 'Derivatives%2020241022.xlsx', Riga: 43560, Nome azienda (completo): 'Proximus': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Proximus
# File: 'Derivatives%2020241022.xlsx', Riga: 43742, Nome azienda (completo): 'Sofina - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Sofina
# File: 'Derivatives%2020241022.xlsx', Riga: 43848, Nome azienda (completo): 'Solvay - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Solvay
# File: 'Derivatives%2020241022.xlsx', Riga: 44066, Nome azienda (completo): 'Solvay ex-event package': Questa cella contiene il nome di un'azienda? (s/no): n
# Azienda aggiunta alla blacklist: Solvay ex-event package
# File: 'Derivatives%2020241022.xlsx', Riga: 44080, Nome azienda (completo): 'Syensqo - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Syensqo
# File: 'Derivatives%2020241022.xlsx', Riga: 44266, Nome azienda (completo): 'UCB': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: UCB
# File: 'Derivatives%2020241022.xlsx', Riga: 44604, Nome azienda (completo): 'Umicore': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Umicore
# File: 'Derivatives%2020241022.xlsx', Riga: 44830, Nome azienda (completo): 'Warehouses de Pauw - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Warehouses de Pauw
# File: 'Derivatives%2020241022.xlsx', Riga: 44934, Nome azienda (completo): 'ageas NV/SA (B)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: ageas NV/SA (B)
# File: 'Derivatives%2020241022.xlsx', Riga: 45114, Nome azienda (completo): 'bpost NV - Standard Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: bpost NV
# File: 'Derivatives%2020241022.xlsx', Riga: 45296, Nome azienda (completo): 'Galp Energia, SGPS, S.A.': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Galp Energia, SGPS, S.A.
# File: 'Derivatives%2020241022.xlsx', Riga: 45322, Nome azienda (completo): 'Jeronimo Martins STND FUT': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Jeronimo Martins STND FUT
# File: 'Derivatives%2020241022.xlsx', Riga: 45334, Nome azienda (completo): 'Redes Energeticas Nacionais SA - STND FUT': Questa cella contiene il nome di un'azienda? (s/no): n
# Azienda aggiunta alla blacklist: Redes Energeticas Nacionais SA - STND FUT
# File: 'Derivatives%2020241022.xlsx', Riga: 45357, Nome azienda (completo): 'EDP Energias de Portugal SA - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: EDP Energias de Portugal SA
# File: 'Derivatives%2020241022.xlsx', Riga: 45443, Nome azienda (completo): 'EDP Renovaveis - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: EDP Renovaveis
# File: 'Derivatives%2020241022.xlsx', Riga: 45539, Nome azienda (completo): 'Galp Energia SGPS SA - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Galp Energia SGPS SA
# File: 'Derivatives%2020241022.xlsx', Riga: 45623, Nome azienda (completo): 'Jeronimo Martins SGPS SA - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Jeronimo Martins SGPS SA
# File: 'Derivatives%2020241022.xlsx', Riga: 45713, Nome azienda (completo): 'FTSE MIB Div Ind Fut': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: FTSE MIB Div Ind Fut
# File: 'Derivatives%2020241022.xlsx', Riga: 45728, Nome azienda (completo): 'FTSE MIB - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: FTSE MIB
# File: 'Derivatives%2020241022.xlsx', Riga: 45856, Nome azienda (completo): 'FTSE MIB Index Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: FTSE MIB Index Option
# File: 'Derivatives%2020241022.xlsx', Riga: 47352, Nome azienda (completo): 'A2A - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: A2A
# File: 'Derivatives%2020241022.xlsx', Riga: 48144, Nome azienda (completo): 'ANIMA Holding - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: ANIMA Holding
# File: 'Derivatives%2020241022.xlsx', Riga: 48460, Nome azienda (completo): 'Acea - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Acea
# File: 'Derivatives%2020241022.xlsx', Riga: 48766, Nome azienda (completo): 'Amplifon - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Amplifon
# File: 'Derivatives%2020241022.xlsx', Riga: 49080, Nome azienda (completo): 'Ariston Holding - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Ariston Holding
# File: 'Derivatives%2020241022.xlsx', Riga: 49428, Nome azienda (completo): 'Azimut Holding - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Azimut Holding
# File: 'Derivatives%2020241022.xlsx', Riga: 49724, Nome azienda (completo): 'BFF Bank - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: BFF Bank
# File: 'Derivatives%2020241022.xlsx', Riga: 50386, Nome azienda (completo): 'BPER Banca - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: BPER Banca
# File: 'Derivatives%2020241022.xlsx', Riga: 51726, Nome azienda (completo): 'Banca Generali - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Banca Generali
# File: 'Derivatives%2020241022.xlsx', Riga: 52480, Nome azienda (completo): 'Banca Ifis - Stock Option Physical': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Banca Ifis
# File: 'Derivatives%2020241022.xlsx', Riga: 52796, Nome azienda (completo): 'Banca Mediolanum - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Banca Mediolanum
# File: 'Derivatives%2020241022.xlsx', Riga: 53088, Nome azienda (completo): 'Banca Monte Paschi Siena - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Banca Monte Paschi Siena
# File: 'Derivatives%2020241022.xlsx', Riga: 53928, Nome azienda (completo): 'Banca Popolare Sondrio - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Banca Popolare Sondrio
# File: 'Derivatives%2020241022.xlsx', Riga: 54860, Nome azienda (completo): 'Banco BPM - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Banco BPM
# File: 'Derivatives%2020241022.xlsx', Riga: 56116, Nome azienda (completo): 'Brembo - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Brembo
# File: 'Derivatives%2020241022.xlsx', Riga: 56862, Nome azienda (completo): 'Brunello Cucinelli - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Brunello Cucinelli
# File: 'Derivatives%2020241022.xlsx', Riga: 57230, Nome azienda (completo): 'Buzzi - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Buzzi
# File: 'Derivatives%2020241022.xlsx', Riga: 57542, Nome azienda (completo): 'CAREL Industries - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: CAREL Industries
# File: 'Derivatives%2020241022.xlsx', Riga: 58220, Nome azienda (completo): 'Campari - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Campari
# File: 'Derivatives%2020241022.xlsx', Riga: 58568, Nome azienda (completo): 'Danieli & C. - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Danieli & C.
# File: 'Derivatives%2020241022.xlsx', Riga: 58912, Nome azienda (completo): 'De'Longhi - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: De'Longhi
# File: 'Derivatives%2020241022.xlsx', Riga: 59222, Nome azienda (completo): 'DiaSorin - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: DiaSorin
# File: 'Derivatives%2020241022.xlsx', Riga: 59540, Nome azienda (completo): 'ENAV - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: ENAV
# File: 'Derivatives%2020241022.xlsx', Riga: 59848, Nome azienda (completo): 'ERG - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: ERG
# File: 'Derivatives%2020241022.xlsx', Riga: 61556, Nome azienda (completo): 'Enel - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Enel
# File: 'Derivatives%2020241022.xlsx', Riga: 64534, Nome azienda (completo): 'Eni - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Eni
# File: 'Derivatives%2020241022.xlsx', Riga: 66712, Nome azienda (completo): 'Ferrari - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Ferrari
# File: 'Derivatives%2020241022.xlsx', Riga: 69276, Nome azienda (completo): 'Fincantieri - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Fincantieri
# File: 'Derivatives%2020241022.xlsx', Riga: 69928, Nome azienda (completo): 'FinecoBank - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: FinecoBank
# File: 'Derivatives%2020241022.xlsx', Riga: 70680, Nome azienda (completo): 'GEOX - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: GEOX
# File: 'Derivatives%2020241022.xlsx', Riga: 70986, Nome azienda (completo): 'GVS - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: GVS
# File: 'Derivatives%2020241022.xlsx', Riga: 72748, Nome azienda (completo): 'Generali - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Generali
# File: 'Derivatives%2020241022.xlsx', Riga: 74342, Nome azienda (completo): 'Hera - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Hera
# File: 'Derivatives%2020241022.xlsx', Riga: 74642, Nome azienda (completo): 'INWIT - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: INWIT
# File: 'Derivatives%2020241022.xlsx', Riga: 74924, Nome azienda (completo): 'Industrie De Nora - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Industrie De Nora
# File: 'Derivatives%2020241022.xlsx', Riga: 75256, Nome azienda (completo): 'Interpump Group - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Interpump Group
# File: 'Derivatives%2020241022.xlsx', Riga: 77082, Nome azienda (completo): 'Intesa Sanpaolo - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Intesa Sanpaolo
# File: 'Derivatives%2020241022.xlsx', Riga: 78782, Nome azienda (completo): 'Iren - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Iren
# File: 'Derivatives%2020241022.xlsx', Riga: 79078, Nome azienda (completo): 'Italgas - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Italgas
# File: 'Derivatives%2020241022.xlsx', Riga: 79374, Nome azienda (completo): 'Iveco Group - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Iveco Group
# File: 'Derivatives%2020241022.xlsx', Riga: 79724, Nome azienda (completo): 'Juventus Football Club - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Juventus Football Club
# File: 'Derivatives%2020241022.xlsx', Riga: 80068, Nome azienda (completo): 'Leonardo - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Leonardo
# File: 'Derivatives%2020241022.xlsx', Riga: 81374, Nome azienda (completo): 'Lottomatica Group - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Lottomatica Group
# File: 'Derivatives%2020241022.xlsx', Riga: 81656, Nome azienda (completo): 'MFE B - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: MFE B
# File: 'Derivatives%2020241022.xlsx', Riga: 81994, Nome azienda (completo): 'Maire - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Maire
# File: 'Derivatives%2020241022.xlsx', Riga: 82632, Nome azienda (completo): 'Mediobanca - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Mediobanca
# File: 'Derivatives%2020241022.xlsx', Riga: 84516, Nome azienda (completo): 'Moncler - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Moncler
# File: 'Derivatives%2020241022.xlsx', Riga: 84856, Nome azienda (completo): 'Mondadori Editore - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Mondadori Editore
# File: 'Derivatives%2020241022.xlsx', Riga: 85458, Nome azienda (completo): 'Nexi - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Nexi
# File: 'Derivatives%2020241022.xlsx', Riga: 86220, Nome azienda (completo): 'OVS - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: OVS
# File: 'Derivatives%2020241022.xlsx', Riga: 86548, Nome azienda (completo): 'Piaggio & C. - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Piaggio & C.
# File: 'Derivatives%2020241022.xlsx', Riga: 87140, Nome azienda (completo): 'Pirelli & C. - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Pirelli & C.
# File: 'Derivatives%2020241022.xlsx', Riga: 89274, Nome azienda (completo): 'Poste Italiane - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Poste Italiane
# File: 'Derivatives%2020241022.xlsx', Riga: 90340, Nome azienda (completo): 'Prysmian - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Prysmian
# File: 'Derivatives%2020241022.xlsx', Riga: 90668, Nome azienda (completo): 'Rai Way - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Rai Way
# File: 'Derivatives%2020241022.xlsx', Riga: 90962, Nome azienda (completo): 'Recordati - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Recordati
# File: 'Derivatives%2020241022.xlsx', Riga: 91252, Nome azienda (completo): 'Reply - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Reply
# File: 'Derivatives%2020241022.xlsx', Riga: 91964, Nome azienda (completo): 'STMicroelectronics - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: STMicroelectronics
# File: 'Derivatives%2020241022.xlsx', Riga: 92812, Nome azienda (completo): 'Safilo Group - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Safilo Group
# File: 'Derivatives%2020241022.xlsx', Riga: 93454, Nome azienda (completo): 'Saipem - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Saipem
# File: 'Derivatives%2020241022.xlsx', Riga: 94330, Nome azienda (completo): 'Salvatore Ferragamo - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Salvatore Ferragamo
# File: 'Derivatives%2020241022.xlsx', Riga: 95242, Nome azienda (completo): 'Sanlorenzo - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Sanlorenzo
# File: 'Derivatives%2020241022.xlsx', Riga: 95566, Nome azienda (completo): 'Sesa - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Sesa
# File: 'Derivatives%2020241022.xlsx', Riga: 96506, Nome azienda (completo): 'Snam - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Snam
# File: 'Derivatives%2020241022.xlsx', Riga: 98914, Nome azienda (completo): 'Stellantis - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Stellantis
# File: 'Derivatives%2020241022.xlsx', Riga: 100738, Nome azienda (completo): 'Tamburi Investment Partners - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Tamburi Investment Partners
# File: 'Derivatives%2020241022.xlsx', Riga: 101022, Nome azienda (completo): 'Technogym - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Technogym
# File: 'Derivatives%2020241022.xlsx', Riga: 101310, Nome azienda (completo): 'Technoprobe - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Technoprobe
# File: 'Derivatives%2020241022.xlsx', Riga: 103134, Nome azienda (completo): 'Telecom Italia - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Telecom Italia
# File: 'Derivatives%2020241022.xlsx', Riga: 106246, Nome azienda (completo): 'Telecom Italia Rsp - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Telecom Italia Rsp
# File: 'Derivatives%2020241022.xlsx', Riga: 107336, Nome azienda (completo): 'Tenaris - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Tenaris
# File: 'Derivatives%2020241022.xlsx', Riga: 108430, Nome azienda (completo): 'Terna - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Terna
# File: 'Derivatives%2020241022.xlsx', Riga: 110398, Nome azienda (completo): 'UniCredit - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: UniCredit
# File: 'Derivatives%2020241022.xlsx', Riga: 112322, Nome azienda (completo): 'Unipol - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Unipol
# File: 'Derivatives%2020241022.xlsx', Riga: 113948, Nome azienda (completo): 'Webuild - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Webuild
# File: 'Derivatives%2020241022.xlsx', Riga: 114280, Nome azienda (completo): 'OBX Index Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: OBX Index Option
# File: 'Derivatives%2020241022.xlsx', Riga: 115204, Nome azienda (completo): 'Aker BP - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Aker BP
# File: 'Derivatives%2020241022.xlsx', Riga: 115354, Nome azienda (completo): 'Aker Carbon Capture - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Aker Carbon Capture
# File: 'Derivatives%2020241022.xlsx', Riga: 115426, Nome azienda (completo): 'Aker Solutions - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Aker Solutions
# File: 'Derivatives%2020241022.xlsx', Riga: 115580, Nome azienda (completo): 'AutoStore Holdings - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: AutoStore Holdings
# File: 'Derivatives%2020241022.xlsx', Riga: 115666, Nome azienda (completo): 'DNB Bank - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: DNB Bank
# File: 'Derivatives%2020241022.xlsx', Riga: 115802, Nome azienda (completo): 'DNO - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: DNO
# File: 'Derivatives%2020241022.xlsx', Riga: 115924, Nome azienda (completo): 'Elkem - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Elkem
# ...
# Azienda aggiunta: Casino Guichard Perrachon (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 133346, Nome azienda (completo): 'Clariane - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Clariane
# File: 'Derivatives%2020241022.xlsx', Riga: 133582, Nome azienda (completo): 'Coface - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Coface
# File: 'Derivatives%2020241022.xlsx', Riga: 133664, Nome azienda (completo): 'Covivio - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Covivio
# File: 'Derivatives%2020241022.xlsx', Riga: 133908, Nome azienda (completo): 'Credit Agricole (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Credit Agricole (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 134388, Nome azienda (completo): 'Credit Agricole - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Credit Agricole
# File: 'Derivatives%2020241022.xlsx', Riga: 134502, Nome azienda (completo): 'DBV Technologies - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: DBV Technologies
# File: 'Derivatives%2020241022.xlsx', Riga: 134578, Nome azienda (completo): 'Danone (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Danone (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 134946, Nome azienda (completo): 'Danone - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Danone
# File: 'Derivatives%2020241022.xlsx', Riga: 135036, Nome azienda (completo): 'Dassault Aviation - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Dassault Aviation
# File: 'Derivatives%2020241022.xlsx', Riga: 135038, Nome azienda (completo): 'Dassault Systemes (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Dassault Systemes (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 135386, Nome azienda (completo): 'ENGIE (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: ENGIE (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 135892, Nome azienda (completo): 'ENGIE - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: ENGIE
# File: 'Derivatives%2020241022.xlsx', Riga: 136008, Nome azienda (completo): 'Eiffage - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Eiffage
# File: 'Derivatives%2020241022.xlsx', Riga: 136226, Nome azienda (completo): 'Elior Group - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Elior Group
# File: 'Derivatives%2020241022.xlsx', Riga: 136456, Nome azienda (completo): 'Elis - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Elis
# File: 'Derivatives%2020241022.xlsx', Riga: 136562, Nome azienda (completo): 'EssilorLuxottica (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: EssilorLuxottica (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 136958, Nome azienda (completo): 'Eurazeo - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Eurazeo
# File: 'Derivatives%2020241022.xlsx', Riga: 137164, Nome azienda (completo): 'Euroapi - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Euroapi
# File: 'Derivatives%2020241022.xlsx', Riga: 137298, Nome azienda (completo): 'Eurofins Scientific Group SA - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Eurofins Scientific Group SA
# File: 'Derivatives%2020241022.xlsx', Riga: 137598, Nome azienda (completo): 'FDJ - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: FDJ
# File: 'Derivatives%2020241022.xlsx', Riga: 137774, Nome azienda (completo): 'Forvia (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Forvia (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 138074, Nome azienda (completo): 'GENFIT - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: GENFIT
# File: 'Derivatives%2020241022.xlsx', Riga: 138210, Nome azienda (completo): 'GTT - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: GTT
# File: 'Derivatives%2020241022.xlsx', Riga: 138384, Nome azienda (completo): 'Hermes International - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Hermes International
# File: 'Derivatives%2020241022.xlsx', Riga: 138634, Nome azienda (completo): 'Icade - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Icade
# File: 'Derivatives%2020241022.xlsx', Riga: 138932, Nome azienda (completo): 'Imerys - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Imerys
# File: 'Derivatives%2020241022.xlsx', Riga: 139172, Nome azienda (completo): 'Ipsen - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Ipsen
# File: 'Derivatives%2020241022.xlsx', Riga: 139264, Nome azienda (completo): 'Ipsos - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Ipsos
# File: 'Derivatives%2020241022.xlsx', Riga: 139384, Nome azienda (completo): 'KERING (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: KERING (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 139954, Nome azienda (completo): 'L'Oreal (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: L'Oreal (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 140366, Nome azienda (completo): 'L'Oreal - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: L'Oreal
# File: 'Derivatives%2020241022.xlsx', Riga: 140472, Nome azienda (completo): 'LVMH (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: LVMH (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 141082, Nome azienda (completo): 'LVMH - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: LVMH
# File: 'Derivatives%2020241022.xlsx', Riga: 141232, Nome azienda (completo): 'Legrand SA  Std Options': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Legrand SA  Std Options
# File: 'Derivatives%2020241022.xlsx', Riga: 141346, Nome azienda (completo): 'Metropole Television (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Metropole Television (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 141522, Nome azienda (completo): 'Michelin (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Michelin (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 142348, Nome azienda (completo): 'Nanobiotix - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Nanobiotix
# File: 'Derivatives%2020241022.xlsx', Riga: 142568, Nome azienda (completo): 'Neoen SA Stock option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Neoen SA Stock option
# File: 'Derivatives%2020241022.xlsx', Riga: 142650, Nome azienda (completo): 'Nexity - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Nexity
# File: 'Derivatives%2020241022.xlsx', Riga: 142866, Nome azienda (completo): 'OVH - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: OVH
# File: 'Derivatives%2020241022.xlsx', Riga: 143118, Nome azienda (completo): 'Orange - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Orange
# File: 'Derivatives%2020241022.xlsx', Riga: 143230, Nome azienda (completo): 'Orange SA (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Orange SA (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 143720, Nome azienda (completo): 'Pernod Ricard (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Pernod Ricard (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 144162, Nome azienda (completo): 'Pluxee - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Pluxee
# File: 'Derivatives%2020241022.xlsx', Riga: 144516, Nome azienda (completo): 'Publicis Groupe (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Publicis Groupe (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 144728, Nome azienda (completo): 'Renault (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Renault (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 145254, Nome azienda (completo): 'Rexel - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Rexel
# File: 'Derivatives%2020241022.xlsx', Riga: 145362, Nome azienda (completo): 'Rubis - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Rubis
# File: 'Derivatives%2020241022.xlsx', Riga: 145470, Nome azienda (completo): 'SES - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: SES
# File: 'Derivatives%2020241022.xlsx', Riga: 145726, Nome azienda (completo): 'SMCP - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: SMCP
# File: 'Derivatives%2020241022.xlsx', Riga: 145836, Nome azienda (completo): 'SPIE - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: SPIE
# File: 'Derivatives%2020241022.xlsx', Riga: 146076, Nome azienda (completo): 'STMicroelectronics (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: STMicroelectronics (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 146582, Nome azienda (completo): 'Safran SA (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Safran SA (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 146928, Nome azienda (completo): 'Saint Gobain (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Saint Gobain (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 147472, Nome azienda (completo): 'Saint Gobain - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Saint Gobain
# File: 'Derivatives%2020241022.xlsx', Riga: 147770, Nome azienda (completo): 'Sanofi - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Sanofi
# File: 'Derivatives%2020241022.xlsx', Riga: 148046, Nome azienda (completo): 'Sanofi ex-event': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Sanofi ex
# File: 'Derivatives%2020241022.xlsx', Riga: 148212, Nome azienda (completo): 'Schneider Electric (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Schneider Electric (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 148560, Nome azienda (completo): 'Schneider Electric - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Schneider Electric
# File: 'Derivatives%2020241022.xlsx', Riga: 148656, Nome azienda (completo): 'Scor  (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Scor  (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 148938, Nome azienda (completo): 'Societe BIC - Stnd Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Societe BIC
# File: 'Derivatives%2020241022.xlsx', Riga: 149060, Nome azienda (completo): 'Societe Generale (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Societe Generale (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 149636, Nome azienda (completo): 'Societe Generale - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Societe Generale
# File: 'Derivatives%2020241022.xlsx', Riga: 149866, Nome azienda (completo): 'Sodexo - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Sodexo
# File: 'Derivatives%2020241022.xlsx', Riga: 150084, Nome azienda (completo): 'Sodexo SA (100) ex-event package': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Sodexo SA (100) ex
# File: 'Derivatives%2020241022.xlsx', Riga: 150106, Nome azienda (completo): 'Soitec - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Soitec
# File: 'Derivatives%2020241022.xlsx', Riga: 150372, Nome azienda (completo): 'Stellantis (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Stellantis (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 151204, Nome azienda (completo): 'TF1 (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: TF1 (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 151518, Nome azienda (completo): 'Technip Energies - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Technip Energies
# File: 'Derivatives%2020241022.xlsx', Riga: 151696, Nome azienda (completo): 'Thales (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Thales (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 151994, Nome azienda (completo): 'TotalEnergies (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: TotalEnergies (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 152502, Nome azienda (completo): 'TotalEnergies - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: TotalEnergies
# File: 'Derivatives%2020241022.xlsx', Riga: 152608, Nome azienda (completo): 'Trigano SA - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Trigano SA
# File: 'Derivatives%2020241022.xlsx', Riga: 152840, Nome azienda (completo): 'Ubisoft Entertainment - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Ubisoft Entertainment
# File: 'Derivatives%2020241022.xlsx', Riga: 153238, Nome azienda (completo): 'Valeo (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Valeo (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 153486, Nome azienda (completo): 'Vallourec (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Vallourec (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 153682, Nome azienda (completo): 'Valneva SE - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Valneva SE
# File: 'Derivatives%2020241022.xlsx', Riga: 153912, Nome azienda (completo): 'Veolia Environnement (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Veolia Environnement (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 154312, Nome azienda (completo): 'Verallia - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Verallia
# File: 'Derivatives%2020241022.xlsx', Riga: 154410, Nome azienda (completo): 'Vinci (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Vinci (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 154806, Nome azienda (completo): 'Vinci - Weekly Option 1st Friday': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Vinci
# File: 'Derivatives%2020241022.xlsx', Riga: 154908, Nome azienda (completo): 'Vivendi (100)': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Vivendi (100)
# File: 'Derivatives%2020241022.xlsx', Riga: 155288, Nome azienda (completo): 'VusionGroup - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: VusionGroup
# File: 'Derivatives%2020241022.xlsx', Riga: 155492, Nome azienda (completo): 'Worldline - Stock Option': Questa cella contiene il nome di un'azienda? (s/no): s
# Azienda aggiunta: Worldline
# Processing file: Derivatives%2020241024.xlsx
# Tabella delle aziende popolata con successo.

# %%
print(processed_companies)
# Out:
# {'Porsche pref.', 'Worldline', 'Euronext', 'Deutsche Lufthansa', 'Verallia', 'EUE Stock Option (Underlying: iShares Core EURO STOXX 50 UCI', 'Aker BP', 'Publicis Groupe (100)', 'Symrise', 'Zalando', 'AMG N.V.', 'Allianz', 'Deutsche Boerse', 'Corn / Mais', 'AGFA GEVAERT', 'AEX Weekly', 'Brenntag', 'EDP Renovaveis', 'Salvatore Ferragamo', 'Snam', 'Siemens Healthineers', 'Covivio', 'ENAV', 'Amplifon', 'Societe Generale (100)', 'CAREL Industries', 'Azelis Group NV', 'Corbion NV', 'Norsk Hydro', 'SPIE', 'RWE AG', 'BNP Paribas (100)', 'BPER Banca', 'Pernod Ricard (100)', 'Syensqo', 'BFF Bank', 'Generali', 'Elior Group', 'Orange SA (100)', 'Alfen', 'Sanofi ex', 'Hera', 'Ayvens', 'Intesa Sanpaolo', 'Saint Gobain (100)', 'Ferrovial', 'Commerzbank', 'Atos (100)', 'MFE B', 'Rai Way', 'Sanlorenzo', 'GTT', 'Ubisoft Entertainment', 'Webuild', 'AB Science', 'Kerry Group', 'Legrand SA  Std Options', 'Safran SA (100)', 'Axa', 'ASR Nederland', 'RELX (EUR)', 'Rubis', 'Equinor', 'TGS ASA', 'GEOX', 'Acea', 'Pluxee', 'Michelin (100)', 'Colruyt N.V.', 'Anheuser', 'Biomerieux', 'Technip Energies', 'Industrie De Nora', 'Rheinmetall', 'Yara International', 'BNP Paribas', 'Glanbia', 'Galp Energia SGPS SA', 'IBA', 'Sif Holding', 'Norwegian Air Shuttle', 'SAP', 'Brunel International NV Stnd Option', 'Ariston Holding', 'Bouygues (100)', 'Tomra Systems', 'FTSE MIB', 'Qiagen', 'Schneider Electric', 'Siemens AG', "De'Longhi", 'TF1 (100)', 'ING Groep Weekly Option', 'Just Eat Takeaway.com', "L'Oreal (100)", 'KBC Groep', 'Lottomatica Group', 'SBM Offshore NV', 'SES', 'VusionGroup', 'Inpost S.A.', 'Daimler Truck Holding', 'Ontex', 'Enel', 'Fincantieri', 'A2A', 'NN Group NV', 'Signify', 'FTSE MIB Index Option', 'REC Silicon', 'Cofinimmo', 'AEX Daily Option', 'Brunello Cucinelli', 'Euronext Eurozone ESG Large 80 Option', 'Golden Ocean Group', 'Ryanair', 'FTSE MIB Div Ind Fut', 'Aperam Stnd Option', 'Proximus', 'CAC 40 Index Option', 'Euronext Eurozone ESG Large 80 Mini Option', 'Subsea 7', 'Accor SA (100)', 'Interpump Group', 'TKH Group NV Stnd Option', 'Deutsche Bank', 'Elia Group', 'Orange', 'Campari', 'ENGIE', 'Bollore (100)', 'Munich Re', 'Thales (100)', "JDE Peet's", 'Fagron STND OPT', 'STMicroelectronics', 'MTU Aero Engines', 'Eni', 'Recordati', 'Eurofins Scientific Group SA', 'Beiersdorf', 'Terna', 'TotalEnergies', 'CAC 40', 'Storebrand', 'Heineken NV', 'Piaggio & C.', 'Imerys', 'DiaSorin', 'ANIMA Holding', 'Coface', 'ENGIE (100)', 'INWIT', 'Brembo', 'RANDSTAD NV', 'Leonardo', 'Unipol', 'Deutsche Telekom', 'FUGRO', 'Vallourec (100)', 'Italgas', 'Eurazeo', 'MPC Container Ship', 'Vivendi (100)', 'Mondadori Editore', 'Renault (100)', 'Valeo (100)', 'Clariane', 'Capgemini', "L'Oreal", 'BEL 20 INDEX OPTION', 'Eiffage', 'Aalberts', 'Banca Monte Paschi Siena', 'Vinci (100)', 'Carrefour SA (100)', 'Amundi', 'Trigano SA', 'Sligro Food Group NV', 'Technogym', 'Iren', 'Tenaris', 'IMCD', 'Danone (100)', 'Volkswagen pref', 'Saipem', 'ERG', 'Dassault Systemes (100)', 'Aedifica', 'Technoprobe', 'Telecom Italia Rsp', 'Galp Energia, SGPS, S.A.', 'Banca Mediolanum', 'Veolia Environnement (100)', 'Alstom (100)', 'Pirelli & C.', 'Ahold Delhaize, Koninklijke', 'Coca', 'ABN AMRO Bank', 'Nexi', 'Arkema SA', 'Saint Gobain', 'Adyen (10)', 'Vonovia', 'ageas NV/SA', 'ASML Holding NV', 'Aeroports de Paris', 'Galapagos', 'TotalEnergies (100)', 'Allfunds Group PLC', 'Unilever PLC', 'Banca Popolare Sondrio', 'UniCredit', 'Scor  (100)', 'Porsche Automobil Holding pref.', 'Adidas', 'Ackermans & van Haaren NV', 'GVS', 'Sodexo', 'DSM', 'Prosus', 'Credit Agricole', 'Ipsos', 'LVMH', 'KERING (100)', 'Societe Generale', 'Merck', 'WOLTERS', 'Danieli & C.', 'NOKIA', 'DNB Bank', 'Bureau Veritas', 'SMCP', 'UNILEVER PLC', 'Azimut Holding', 'Banco BPM', 'Siemens Energy AG', 'AEX Index Option', 'Icade', 'Henkel', 'Henkel pref.', 'Tamburi Investment Partners', 'Soitec', 'Jeronimo Martins SGPS SA', 'Sesa', 'Airbus', 'CAC 40 Daily Option', 'UCB', 'Arcadis N.V', 'Elis', 'STMicroelectronics (100)', 'Nordic  ...

# %%
# Creazione del database e delle tabelle
conn = sqlite3.connect('financial_data.db')
cursor = conn.cursor()

# Tabella delle aziende
cursor.execute("CREATE TABLE IF NOT EXISTS companies (id INTEGER PRIMARY KEY, name TEXT UNIQUE)")
# Tabella delle date per ogni azienda
cursor.execute("CREATE TABLE IF NOT EXISTS company_dates (company_id INTEGER, date TEXT, UNIQUE(company_id, date))")

# Carica aziende già esistenti
cursor.execute("SELECT name, id FROM companies")
company_ids = {name: company_id for name, company_id in cursor.fetchall()}

# Percorso della cartella
folder_path = 'excel_files'
# Elenco dei file Excel nella cartella (limita a 2 file per test)
excel_files = [f for f in os.listdir(folder_path) if f.endswith('.xlsx')][:2]

for file_name in excel_files:
    print(f"Processing file: {file_name}")
    file_path = os.path.join(folder_path, file_name)

    # Leggi il terzo foglio del file Excel
    df = pd.read_excel(file_path, sheet_name=2, header=None, skiprows=4)  # Salta le prime 4 righe

    # Controlla ogni riga per ogni azienda
    for row_idx, row in df.iterrows():
        potential_name = row[5]  # La sesta colonna è in posizione 5
        if pd.isna(potential_name):
            continue

        base_name = potential_name.split('-')[0].strip()
        # Escludi tipi di contratti indesiderati
        if any(word in potential_name.lower() for word in ["future", "dividend", "european"]):
            continue

        # Aggiungi la data se l'azienda è nel database
        date_value = row[0]  # Assumendo che la data sia nella prima colonna
        if pd.notna(date_value) and base_name in company_ids:
            company_id = company_ids[base_name]

            # Verifica e conversione di date_value a stringa
            date_value_str = str(date_value) if not isinstance(date_value, str) else date_value

            # Inserisci la data per l'azienda, se non già esistente
            cursor.execute("INSERT OR IGNORE INTO company_dates (company_id, date) VALUES (?, ?)", (company_id, date_value_str))
            print(f"Aggiunta data per {base_name}: {date_value_str}")

# Salva le modifiche e chiudi la connessione
conn.commit()
conn.close()
print("Date per azienda aggiunte con successo.")
# Out:
# Output streaming troncato alle ultime 5000 righe.
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale (100): 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Societe Generale: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Sodexo SA (100) ex: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Soitec: 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# Aggiunta data per Stellantis (100): 2024-10-22 00:00:00
# ...
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Aggiunta data per Worldline: 2024-10-22 00:00:00
# Processing file: Derivatives%2020241024.xlsx
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-ab094f2a6a16> in <cell line: 23>()
#      26
#      27     # Leggi il terzo foglio del file Excel
# ---> 28     df = pd.read_excel(file_path, sheet_name=2, header=None, skiprows=4)  # Salta le prime 4 righe
#      29
#      30     # Controlla ogni riga per ogni azienda
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     506
#     507     try:
# --> 508         data = io.parse(
#     509             sheet_name=sheet_name,
#     510             header=header,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1614         >>> file.parse()  # doctest: +SKIP
#    1615         """
# -> 1616         return self._reader.parse(
#    1617             sheet_name=sheet_name,
#    1618             header=header,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     776
#     777             file_rows_needed = self._calc_rows(header, index_col, skiprows, nrows)
# --> 778             data = self.get_sheet_data(sheet, file_rows_needed)
#     779             if hasattr(sheet, "close"):
#     780                 # pyxlsb opens two TemporaryFiles
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_openpyxl.py in get_sheet_data(self, sheet, file_rows_needed)
#     613         data: list[list[Scalar]] = []
#     614         last_row_with_data = -1
# --> 615         for row_number, row in enumerate(sheet.rows):
#     616             converted_row = [self._convert_cell(cell) for cell in row]
#     617             while converted_row and converted_row[-1] == "":
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_read_only.py in _cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      83                                      timedelta_formats=self.parent._timedelta_formats)
#      84
# ---> 85             for idx, row in parser.parse():
#      86                 if max_row is not None and idx > max_row:
#      87                     break
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py in parse(self)
#     154         it = iterparse(self.source) # add a finaliser to close the source when this becomes possible
#     155
# --> 156         for _, element in it:
#     157             tag_name = element.tag
#     158             if tag_name in dispatcher:
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in iterator(source)
#    1256                 if not data:
#    1257                     break
# -> 1258                 pullparser.feed(data)
#    1259             root = pullparser._close_and_return_root()
#    1260             yield from pullparser.read_events()
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in feed(self, data)
#    1294         if data:
#    1295             try:
# -> 1296                 self._parser.feed(data)
#    1297             except SyntaxError as exc:
#    1298                 self._events_queue.append(exc)
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in feed(self, data)
#    1711         """Feed encoded data to parser."""
#    1712         try:
# -> 1713             self.parser.Parse(data, False)
#    1714         except self._error as v:
#    1715             self._raiseerror(v)
#
# ../Modules/pyexpat.c in StartElement()
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in _start(self, tag, attr_list)
#    1639         return self.target.end_ns(prefix or '')
#    1640
# -> 1641     def _start(self, tag, attr_list):
#    1642         # Handler for expat's StartElementHandler. Since ordered_attributes
#    1643         # is set, the attributes are reported as a list of alternating
#
# KeyboardInterrupt:

# %%
def ensure_database_exists():
    """
    Ensure database and tables exist, return True if successful, False otherwise.
    """
    try:
        conn = sqlite3.connect('options_data.db')
        cursor = conn.cursor()

        # Create tables if they don't exist
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS options_data (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                date TEXT,
                company TEXT,
                contract_type TEXT,
                strike_price REAL,
                expiry_date TEXT,
                open_interest INTEGER,
                volume INTEGER,
                bid REAL,
                ask REAL
            )
        ''')

        # Create indices
        cursor.execute('''
            CREATE INDEX IF NOT EXISTS idx_options_lookup
            ON options_data(company, date)
        ''')

        cursor.execute('''
            CREATE INDEX IF NOT EXISTS idx_strike_price
            ON options_data(strike_price)
        ''')

        conn.commit()

        # Verify table exists
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name='options_data'")
        if not cursor.fetchone():
            print("Failed to create options_data table")
            return False

        # Verify if table has data
        cursor.execute("SELECT COUNT(*) FROM options_data")
        count = cursor.fetchone()[0]

        if count == 0:
            print("Database exists but is empty. Need to process Excel files.")
            return False

        print(f"Database exists and contains {count} records")
        return True

    except Exception as e:
        print(f"Error checking database: {e}")
        return False
    finally:
        if conn:
            conn.close()

import re

# %%
def clean_column_labels(df):
    """
    Rimuove formattazioni e caratteri speciali dalle etichette di colonna.
    """
    cleaned_columns = {}
    for col in df.columns:
        clean_label = re.sub(r'[\s\n]+', ' ', col).strip().lower()  # Rimuove spazi multipli e a capo
        cleaned_columns[col] = clean_label
    df.rename(columns=cleaned_columns, inplace=True)

    # Mappatura delle colonne in base alle etichette standard
    column_map = {
        'date': 'date',
        'market place': 'market_place',
        'product group': 'product_group',
        'contract type': 'contract_type',
        'contract name': 'contract_name',
        'contract code': 'contract_code',
        'last trading date': 'last_trading_date',
        'expiry month': 'expiry_month',
        'exercise price': 'exercise_price',
        'instrument type': 'instrument_type',
        'valuation coefficient': 'valuation_coefficient',
        'exercise type': 'exercise_type',
        'amr': 'amr',
        'isin': 'isin',
        'currency': 'currency',
        'first price': 'first_price',
        'highest price': 'highest_price',
        'lowest price': 'lowest_price',
        'last price': 'last_price',
        'settlement price': 'settlement_price',
        'volume (total)': 'volume_total',
        'volume (wholesale)': 'volume_wholesale',
        'number of trades (total)': 'num_trades_total',
        'value of volume (total, euro)': 'value_volume_total_euro',
        'premium turnover (total, euro)': 'premium_turnover_total_euro',
        'open interest': 'open_interest',
        'settlement volatility': 'settlement_volatility',
        'settlement delta': 'settlement_delta'
    }

    # Rinomina le colonne del dataframe in base alla mappatura
    df.rename(columns=column_map, inplace=True)
    return df

# %%
def process_excel_files():
    """
    Processa i file Excel, applica la pulizia delle etichette e salva nel database.
    """
    try:
        conn = sqlite3.connect('options_data.db')
        cursor = conn.cursor()

        excel_folder = "excel_files"
        excel_files = list(Path(excel_folder).glob("*.xlsx"))

        for excel_file in excel_files:
            df = pd.read_excel(excel_file, header=3)
            df = clean_column_labels(df)  # Pulizia delle etichette

            # Filtra solo le opzioni
            df_options = df[df['contract_type'].str.contains('Options', case=False, na=False)]

            # Inserisce i dati puliti nel database
            for _, row in df_options.iterrows():
                data = (
                    row['date'], row['contract_name'].split('-')[0].strip(),
                    row['contract_type'], row['exercise_price'], row['expiry_month'],
                    row['open_interest'], row['volume_total'], row.get('bid'), row.get('ask')
                )

                cursor.execute('''
                    INSERT INTO options_data
                    (date, company, contract_type, strike_price, expiry_date, open_interest, volume, bid, ask)
                    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
                ''', data)
            conn.commit()

    finally:
        conn.close()

# %%
def plot_options_open_interest(company_name, date):
    """Create a detailed visualization of options open interest."""
    try:
        conn = sqlite3.connect('options_data.db')

        # Verify data exists for the company and date
        verify_query = '''
            SELECT COUNT(*) FROM options_data
            WHERE company = ? AND date = ?
        '''
        count = conn.execute(verify_query, (company_name, date)).fetchone()[0]

        if count == 0:
            print(f"No data found for {company_name} on {date}")
            return

        print(f"Found {count} records for {company_name} on {date}")

        # Get options data
        query = '''
            SELECT strike_price, contract_type, open_interest, expiry_date
            FROM options_data
            WHERE company = ? AND date = ?
            ORDER BY strike_price, expiry_date
        '''

        df = pd.read_sql_query(query, conn, params=(company_name, date))

        # Create visualization
        plt.figure(figsize=(15, 10))

        # Split data into calls and puts
        calls = df[df['contract_type'].str.contains('CALL', case=False, na=False)]
        puts = df[df['contract_type'].str.contains('PUT', case=False, na=False)]

        # Plot calls above x-axis
        if not calls.empty:
            plt.bar(calls['strike_price'], calls['open_interest'],
                   color='green', alpha=0.6, label='Calls')

        # Plot puts below x-axis
        if not puts.empty:
            plt.bar(puts['strike_price'], -puts['open_interest'],
                   color='red', alpha=0.6, label='Puts')

        plt.title(f'Options Open Interest Distribution\n{company_name} - {date}',
                 fontsize=14, pad=20)
        plt.xlabel('Strike Price', fontsize=12)
        plt.ylabel('Open Interest\n(Puts below axis, Calls above)', fontsize=12)
        plt.grid(True, alpha=0.3)
        plt.legend(loc='upper right')

        # Add statistics
        total_calls_oi = calls['open_interest'].sum() if not calls.empty else 0
        total_puts_oi = puts['open_interest'].sum() if not puts.empty else 0
        put_call_ratio = total_puts_oi / total_calls_oi if total_calls_oi > 0 else float('inf')

        stats_text = (f'Total Calls OI: {total_calls_oi:,.0f}\n'
                     f'Total Puts OI: {total_puts_oi:,.0f}\n'
                     f'Put/Call Ratio: {put_call_ratio:.2f}')

        plt.figtext(0.02, 0.98, stats_text,
                   bbox=dict(facecolor='white', alpha=0.8),
                   fontsize=10, va='top')

        plt.tight_layout()
        plt.show()

    except Exception as e:
        print(f"Error creating visualization: {e}")
    finally:
        if conn:
            conn.close()

# %%
# Main execution
if __name__ == "__main__":
    try:
        # Check if database exists and has data
        if not ensure_database_exists():
            print("Need to process existing Excel files...")
            if process_excel_files():
                print("Dati elaborati correttamente.")
            else:
                raise Exception("Errore nell'elaborazione dei file Excel.")

        # Get user input
        company_name = input("Enter company name: ")
        date = input("Enter date (YYYYMMDD format): ")

        # Create visualization
        plot_options_open_interest(company_name, date)

    except Exception as e:
        print(f"Error in main execution: {e}")
# Out:
# Database exists but is empty. Need to process Excel files.
#
# Connecting to website...
#
# File 'Derivatives%2020241024.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241024.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241023.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241023.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241022.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241022.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241021.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241021.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241018.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241018.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241017.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241017.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241016.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241016.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241015.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241015.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241014.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241014.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241011.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241011.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241010.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241010.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241009.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241009.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241008.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241008.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241007.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241007.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241004.xlsx' already exists. Skipping.
#
# File 'Derivatives%2020241004.xlsx' already exists. Skipping.
#
# Downloading Derivatives%2020241003.xlsx (31/5538)...
# Successfully downloaded 'Derivatives%2020241003.xlsx'
#
# File 'Derivatives%2020241003.xlsx' already exists. Skipping.
#
# Downloading Derivatives%2020241002.xlsx (33/5538)...
# Successfully downloaded 'Derivatives%2020241002.xlsx'
#
# File 'Derivatives%2020241002.xlsx' already exists. Skipping.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1c07eb036ac1> in <cell line: 1>()
#       3     if not ensure_database_exists():
#       4         # Scarica i file Excel se il database non esiste o è vuoto
# ----> 5         if download_excel_files():
#       6             # Elimina i dati esistenti e processa i nuovi file
#       7             if process_excel_files():
#
# <ipython-input-13-6cc13e65d44e> in download_excel_files()
#     104
#     105             try:
# --> 106                 time.sleep(1)
#     107                 print(f"\nDownloading {file_name} ({i+1}/{len(links)})...")
#     108                 excel_file = requests.get(excel_link, timeout=30)
#
# KeyboardInterrupt:
